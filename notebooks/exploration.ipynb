# %% [markdown]
# # Exploration notebook
#
# Scratch space for ad-hoc analysis against the pipeline's database.
# Nothing here is production code — anything worth keeping should be
# moved into `src/` and covered by a test.

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
from src.utils.db import get_engine
from src.extract import load_config

config = load_config()
engine = get_engine()
table_name = config['database']['table_name']

df = pd.read_sql(f'SELECT * FROM {table_name} ORDER BY observation_time DESC', engine)
df.head()

# %%
df.groupby('location_name')['temperature_celsius'].describe()
